# %%
# Install dependencies

# !apt-get install muscle -y
# !pip install biopython


#  Upload your FASTA sequences

from google.colab import files
uploaded = files.upload()   # Upload sequences.fasta here

# Run Multiple Sequence Alignment (MSA)

# !muscle -in sequences.fasta -out aligned.fasta


#  Build Phylogenetic Tree (Neighbor-Joining method)

# !muscle -maketree -in aligned.fasta -out tree.nwk -cluster neighborjoining

# Visualize the Tree in Colab

from Bio import Phylo
import matplotlib.pyplot as plt

tree = Phylo.read("tree.nwk", "newick")
fig = plt.figure(figsize=(12, 12))
Phylo.draw(tree)

# Download Results

files.download("aligned.fasta")   # Download MSA result
files.download("tree.nwk")        # Download Newick tree file
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   muscle
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 244 kB of archives.
# After this operation, 709 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 muscle amd64 1:3.8.1551-2build1 [244 kB]
# Fetched 244 kB in 2s (149 kB/s)
# Selecting previously unselected package muscle.
# (Reading database ... 126371 files and directories currently installed.)
# Preparing to unpack .../muscle_1%3a3.8.1551-2build1_amd64.deb ...
# Unpacking muscle (1:3.8.1551-2build1) ...
# Setting up muscle (1:3.8.1551-2build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 6.4 MB/s eta 0:00:00
# ...
#      <input type="file" id="files-fab30deb-27d3-442e-84df-ba55903af0c7" name="files[]" multiple disabled
# ...
